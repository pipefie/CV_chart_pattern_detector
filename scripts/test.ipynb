# %%
# scripts/test.ipynb
import pandas as pd
import sys
from pathlib import Path
import os

# For notebooks, use the current working directory
sys.path.insert(0, str(Path.cwd()))

file_path = Path.cwd() / "../data/ohlcv/crypto/BTC-USD.parquet"

data = pd.read_parquet(file_path)

# %%
data.head(10)
# Out:
#                                open      high       low     close      volume
# timestamp_ms
# 2023-11-15 00:00:00+00:00  35551.20  35627.60  35480.27  35496.78   949.99352
# 2023-11-15 01:00:00+00:00  35496.78  35665.45  35368.43  35424.17  1376.10732
# 2023-11-15 02:00:00+00:00  35424.16  35515.04  35360.00  35480.60  2152.51180
# 2023-11-15 03:00:00+00:00  35480.60  35508.72  35370.00  35381.99   724.48299
# 2023-11-15 04:00:00+00:00  35382.00  35578.85  35375.38  35578.84   667.27605
# 2023-11-15 05:00:00+00:00  35578.85  35614.51  35536.21  35600.00   607.33952
# 2023-11-15 06:00:00+00:00  35600.01  35615.62  35522.46  35581.84   773.76190
# 2023-11-15 07:00:00+00:00  35581.83  35661.04  35551.53  35576.88  1152.27256
# 2023-11-15 08:00:00+00:00  35576.88  35837.51  35576.88  35792.11  1855.55118
# 2023-11-15 09:00:00+00:00  35792.10  35950.00  35750.62  35782.57  1785.50199
